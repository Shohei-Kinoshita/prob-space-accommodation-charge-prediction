# %%
from google.colab import drive
drive.mount('/content/drive')
# カレントディレクトリの指定
import os
os.chdir('/content/drive/MyDrive/分析コンペ/05_ProbSpace/民泊サービスの宿泊料金予測/')
# Out:
# Mounted at /content/drive

# %%
import datetime
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import warnings
import xgboost as xgb

from tqdm import tqdm
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, StandardScaler
from geopy.distance import geodesic

from src.config import *

warnings.filterwarnings('ignore')

# %%
def create_elapsed_days(df):
    """
    2020/4/30までの経過日数
    """
    df[COL_ELAPSED_DAYS] = (datetime.datetime(2020, 4, 30) - df[COL_LAST_REVIEW]).dt.days
    return df


def enc_categorical(df, col_list, method):
    """
    カテゴリカル変数に対して、one-hotかlabel-encを行う
    """
    if method == 'one-hot':
        df = pd.get_dummies(df, columns=col_list, drop_first=True)
        return df
    elif method == 'label-enc':
        for col in col_list:
            le = LabelEncoder()
            df[col] = le.fit_transform(df[col])
        return df

# %%
df_train = pd.read_csv('input/train_data.csv', parse_dates=[COL_LAST_REVIEW], dtype=DICT_DTYPES)
df_test = pd.read_csv('input/test_data.csv', parse_dates=[COL_LAST_REVIEW], dtype=DICT_DTYPES)
df_train_station_info = pd.read_csv('input/train_data_distance_from_station.csv', dtype=DICT_DTYPES)
df_test_station_info = pd.read_csv('input/test_data_distance_from_station.csv', dtype=DICT_DTYPES)
df_train_name_features = pd.read_csv('input/train_data_name_features.csv')
df_test_name_features = pd.read_csv('input/test_data_name_features.csv')
df_train_gaussian_mixture = pd.read_csv('input/train_data_gaussianmixture.csv')
df_test_gaussian_mixture = pd.read_csv('input/test_data_gaussianmixture.csv')
df_train_mds = pd.read_csv('input/train_data_mds.csv')
df_test_mds = pd.read_csv('input/test_data_mds.csv')
df_train_nearest_station = pd.read_csv('input/train_data_station_info.csv', usecols=['nearest_station_index'])
df_test_nearest_station = pd.read_csv('input/test_data_station_info.csv', usecols=['nearest_station_index'])
df_train_neighbourhood_roomtype = pd.read_csv('input/train_data_neighbourhood_roomtype.csv', usecols=['neighbourhood_roomtype_le'])
df_test_neighbourhood_roomtype = pd.read_csv('input/test_data_neighbourhood_roomtype.csv', usecols=['neighbourhood_roomtype_le'])
sample_sub = pd.read_csv('input/submission.csv')

# %%
df_all = pd.concat([
    df_train,
    df_test
]).reset_index(drop=True)

# %%
df_all.head()
# Out:
#   id                                               name    host_id  \
# 0  1  KiyosumiShirakawa 3min|★SkyTree★|WIFI|Max4|Tre...  242899459
# 1  2                  Downtown Tokyo Iriya next to Ueno  308879948
# 2  3        Japan Style,Private,Affordable,4min to Sta.  300877823
# 3  4    4 min to Shinjuku Sta. by train / 2 ppl / Wi-fi  236935461
# 4  5      LICENSED SHINJUKU HOUSE: Heart of the action!  243408889
#
#    neighbourhood  latitude  longitude        room_type  minimum_nights  \
# 0        Koto Ku  35.68185  139.80310  Entire home/apt               1
# 1       Taito Ku  35.72063  139.78536  Entire home/apt               6
# 2  Katsushika Ku  35.74723  139.82349  Entire home/apt               1
# 3     Shibuya Ku  35.68456  139.68077  Entire home/apt               1
# 4    Shinjuku Ku  35.69840  139.70467  Entire home/apt               1
#
#    number_of_reviews last_review  reviews_per_month  availability_365  \
# 0                 55  2020-04-25               2.21               173
# 1                 72  2020-03-25               2.11                 9
# 2                 18  2020-03-23               3.46               288
# 3                  2  2020-04-02               1.76                87
# 4                 86  2020-01-30               2.00               156
#
#           y
# 0   12008.0
# 1    6667.0
# 2    9923.0
# 3    8109.0
# 4  100390.0

# %%
# 2020.4.30からの経過日数を特徴量として追加
df_all[COL_ELAPSED_DAYS] = (datetime.datetime(2020, 4, 30) - df_all[COL_LAST_REVIEW]).dt.days

# %%
df_all.fillna(0, inplace=True)

# %%
for col in LIST_ENC_COL:
    le = LabelEncoder()
    df_all[col] = le.fit_transform(df_all[col])

# %%
df_all = df_all[LIST_USE_COL]

# %%
df_all.head()
# Out:
#    neighbourhood  latitude  longitude  room_type  minimum_nights  \
# 0              9  35.68185  139.80310          0               1
# 1             21  35.72063  139.78536          0               6
# 2              7  35.74723  139.82349          0               1
# 3             16  35.68456  139.68077          0               1
# 4             18  35.69840  139.70467          0               1
#
#    number_of_reviews  elapsed_days  reviews_per_month  availability_365
# 0                 55           5.0               2.21               173
# 1                 72          36.0               2.11                 9
# 2                 18          38.0               3.46               288
# 3                  2          28.0               1.76                87
# 4                 86          91.0               2.00               156

# %%
df_all_station_info = pd.concat([df_train_station_info, df_test_station_info], axis=0).reset_index(drop=True)
pipe = Pipeline([
    ('scale', StandardScaler()),
    ('pca', PCA(n_components=10, random_state=0))
])

# %%
features_tmp = pipe.fit_transform(df_all_station_info)
df_features = pd.DataFrame(features_tmp, columns=[f'PCA_{i+1}' for i in range(features_tmp.shape[1])])
df_features.head()
# Out:
#        PCA_1     PCA_2      PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 0  18.653366  0.858400 -13.804691  2.301068 -0.302593  2.757417  0.460876
# 1  17.356235 -8.494013  -0.796745  0.504377 -2.052830 -1.859290  0.186437
# 2  32.363401  6.726955  13.218806  0.054782  2.093366 -2.422866 -1.568053
# 3 -24.277259  0.255721  -0.039130  1.613609  2.273263 -1.378739  0.306705
# 4 -16.020399 -8.673477  -1.703626 -1.104780  2.383075 -0.055141  1.253202
#
#       PCA_8     PCA_9    PCA_10
# 0 -1.628651  0.657036 -0.117527
# 1  0.440242 -0.522165  0.054421
# 2  0.301075 -0.832967  0.726261
# 3 -0.403338 -0.098069 -0.514598
# 4  0.417800 -0.442989  0.166816

# %%
df_train_features = df_features[:df_train.shape[0]].reset_index(drop=True)
df_test_features = df_features[df_train.shape[0]:].reset_index(drop=True)

# %%
X = df_all[:df_train.shape[0]].reset_index(drop=True)
X = pd.concat([X, df_train_features, df_train_name_features, df_train_gaussian_mixture, df_train_mds, df_train_nearest_station, df_train_neighbourhood_roomtype], axis=1)
y = np.log1p(df_train[COL_Y])

X_inference = df_all[df_train.shape[0]:].reset_index(drop=True)
X_inference = pd.concat([X_inference, df_test_features, df_test_name_features, df_test_gaussian_mixture, df_test_mds, df_test_nearest_station, df_test_neighbourhood_roomtype], axis=1)

# %%
X.head()
# Out:
#    neighbourhood  latitude  longitude  room_type  minimum_nights  \
# 0              9  35.68185  139.80310          0               1
# 1             21  35.72063  139.78536          0               6
# 2              7  35.74723  139.82349          0               1
# 3             16  35.68456  139.68077          0               1
# 4             18  35.69840  139.70467          0               1
#
#    number_of_reviews  elapsed_days  reviews_per_month  availability_365  \
# 0                 55           5.0               2.21               173
# 1                 72          36.0               2.11                 9
# 2                 18          38.0               3.46               288
# 3                  2          28.0               1.76                87
# 4                 86          91.0               2.00               156
#
#        PCA_1  ...       mds_3       mds_4       mds_5       mds_6       mds_7  \
# 0  18.653366  ...  -58.109808  176.259606  -37.868741  200.372995  -90.446952
# 1  17.356235  ...  -64.322166  -74.630171  -21.281596  221.457880   33.833832
# 2  32.363401  ... -122.713740   44.936694  183.089396   -4.669583 -100.740114
# 3 -24.277259  ...   33.291650  -53.459711  -65.131115 -122.304476   45.540907
# 4 -16.020399  ...    1.694360 -171.467625 -160.070368  -25.120009   73.119588
#
#         mds_8       mds_9      mds_10  nearest_station_index  \
# 0   97.374829  106.743579 -223.862741                    627
# 1   54.119850  161.492633 -273.066649                    179
# 2  173.948258   63.183299 -507.104732                    694
# 3  -93.036075 -121.970158  388.522576                     80
# 4 -128.352844   -0.527934  287.441065                    346
#
#    neighbourhood_roomtype_le
# 0                         36
# 1                         82
# 2                         28
# 3                         62
# 4                         70
#
# [5 rows x 1421 columns]

# %%
from numpy.ma.core import argsort
def fit_for_xgboost(X, y, model_name):
    """
    KFoldによる学習、検証
    out of foldによる予測をデータフレームで返す
    """
    scores = []
    preds = []
    va_idxes = []
    kf = KFold(n_splits=5, shuffle=True, random_state=0)
    for i, (train_idx, valid_idx) in enumerate(kf.split(X), start=1):
        print('='*50)
        print(f'fold: {i}')
        X_train, X_valid = X.loc[train_idx, :], X.loc[valid_idx, :]
        y_train, y_valid = y[train_idx], y[valid_idx]
        xgb_train = xgb.DMatrix(X_train, label=y_train)
        xgb_test = xgb.DMatrix(X_valid, label=y_valid)
        
        params = {
        'objective': 'reg:squarederror','silent':1, 'random_state':1234, 
        # 学習用の指標 (RMSE)
        'eval_metric': 'rmse',
        }
        num_round = 200
        watchlist = [(xgb_train, 'train'), (xgb_test, 'eval')]#訓練データはdtrain、評価用のテストデータはdvalidと設定

        model = xgb.train(params,
                    xgb_train,#訓練データ
                    num_round,#設定した学習回数
                    early_stopping_rounds=20,
                    evals=watchlist,
                    )

        score = np.sqrt(mean_squared_error(y_valid, model.predict(xgb.DMatrix(X_valid))))
        print(f'mean_squared_log_error: {score}')
        pred = model.predict(xgb.DMatrix(X_valid))
        scores.append(score)
        preds.append(pred)
        va_idxes.append(valid_idx)

        filename = f'models/{model_name}_fold{i}.pkl'
        pickle.dump(model, open(filename, 'wb'))
        print(f'save model: {filename}')
        
    va_idxes = np.concatenate(va_idxes)
    preds = np.concatenate(preds, axis=0)
    order = argsort(va_idxes)
    df_oof = pd.DataFrame(preds[order], columns=[f'{model_name}_stacking'])
    rmsle_mean = np.mean(scores)
    print('='*50)
    print(f'rmsle_mean: {rmsle_mean}')
    print(f'{model_name}_oof')
    print(df_oof.head())
    return df_oof

# %%
df_oof = fit_for_xgboost(X, y, 'xgb')
# Out:
# ==================================================
# fold: 1
# [0]	train-rmse:6.3345	eval-rmse:6.38406
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.47231	eval-rmse:4.51704
# [2]	train-rmse:3.17688	eval-rmse:3.22388
# [3]	train-rmse:2.28035	eval-rmse:2.32947
# [4]	train-rmse:1.66613	eval-rmse:1.72548
# [5]	train-rmse:1.25141	eval-rmse:1.32442
# [6]	train-rmse:0.977137	eval-rmse:1.06452
# [7]	train-rmse:0.802488	eval-rmse:0.904349
# [8]	train-rmse:0.690999	eval-rmse:0.809528
# [9]	train-rmse:0.620397	eval-rmse:0.753625
# [10]	train-rmse:0.566035	eval-rmse:0.718082
# [11]	train-rmse:0.533445	eval-rmse:0.69972
# [12]	train-rmse:0.506788	eval-rmse:0.684725
# [13]	train-rmse:0.48872	eval-rmse:0.680674
# [14]	train-rmse:0.479813	eval-rmse:0.677137
# [15]	train-rmse:0.467711	eval-rmse:0.673053
# [16]	train-rmse:0.461165	eval-rmse:0.671284
# [17]	train-rmse:0.454322	eval-rmse:0.670257
# [18]	train-rmse:0.443359	eval-rmse:0.667702
# [19]	train-rmse:0.436213	eval-rmse:0.66702
# [20]	train-rmse:0.42807	eval-rmse:0.665329
# [21]	train-rmse:0.418296	eval-rmse:0.6629
# [22]	train-rmse:0.408224	eval-rmse:0.658516
# [23]	train-rmse:0.39555	eval-rmse:0.656163
# [24]	train-rmse:0.391601	eval-rmse:0.654577
# [25]	train-rmse:0.384552	eval-rmse:0.652375
# [26]	train-rmse:0.378717	eval-rmse:0.65147
# [27]	train-rmse:0.372066	eval-rmse:0.650598
# [28]	train-rmse:0.366041	eval-rmse:0.64973
# [29]	train-rmse:0.356421	eval-rmse:0.648863
# [30]	train-rmse:0.346486	eval-rmse:0.647724
# [31]	train-rmse:0.341518	eval-rmse:0.647706
# [32]	train-rmse:0.337396	eval-rmse:0.647058
# [33]	train-rmse:0.332045	eval-rmse:0.645349
# [34]	train-rmse:0.328361	eval-rmse:0.64464
# [35]	train-rmse:0.322312	eval-rmse:0.643571
# [36]	train-rmse:0.316653	eval-rmse:0.64229
# [37]	train-rmse:0.311109	eval-rmse:0.640204
# [38]	train-rmse:0.307319	eval-rmse:0.639018
# [39]	train-rmse:0.30462	eval-rmse:0.638272
# [40]	train-rmse:0.300445	eval-rmse:0.638201
# [41]	train-rmse:0.296229	eval-rmse:0.637338
# [42]	train-rmse:0.290151	eval-rmse:0.636626
# [43]	train-rmse:0.284283	eval-rmse:0.635439
# [44]	train-rmse:0.27963	eval-rmse:0.635907
# [45]	train-rmse:0.277703	eval-rmse:0.635562
# [46]	train-rmse:0.274915	eval-rmse:0.634042
# [47]	train-rmse:0.26985	eval-rmse:0.634009
# [48]	train-rmse:0.264923	eval-rmse:0.633673
# [49]	train-rmse:0.259598	eval-rmse:0.633548
# [50]	train-rmse:0.257041	eval-rmse:0.632612
# [51]	train-rmse:0.252213	eval-rmse:0.632647
# [52]	train-rmse:0.24846	eval-rmse:0.632351
# [53]	train-rmse:0.245171	eval-rmse:0.631629
# [54]	train-rmse:0.242155	eval-rmse:0.630479
# [55]	train-rmse:0.238944	eval-rmse:0.630367
# [56]	train-rmse:0.234839	eval-rmse:0.630098
# [57]	train-rmse:0.231464	eval-rmse:0.629806
# [58]	train-rmse:0.229561	eval-rmse:0.629701
# [59]	train-rmse:0.226774	eval-rmse:0.629702
# [60]	train-rmse:0.224698	eval-rmse:0.629571
# [61]	train-rmse:0.223834	eval-rmse:0.629081
# [62]	train-rmse:0.219684	eval-rmse:0.628464
# [63]	train-rmse:0.217994	eval-rmse:0.628363
# [64]	train-rmse:0.214685	eval-rmse:0.628677
# [65]	train-rmse:0.21215	eval-rmse:0.628378
# [66]	train-rmse:0.207695	eval-rmse:0.627803
# [67]	train-rmse:0.205611	eval-rmse:0.628254
# [68]	train-rmse:0.204719	eval-rmse:0.628111
# [69]	train-rmse:0.202781	eval-rmse:0.627245
# [70]	train-rmse:0.200611	eval-rmse:0.626958
# [71]	train-rmse:0.197391	eval-rmse:0.626843
# [72]	train-rmse:0.192396	eval-rmse:0.626117
# [73]	train-rmse:0.190171	eval-rmse:0.626148
# [74]	train-rmse:0.187635	eval-rmse:0.625863
# [75]	train-rmse:0.185384	eval-rmse:0.625915
# [76]	train-rmse:0.183559	eval-rmse:0.625302
# [77]	train-rmse:0.181215	eval-rmse:0.624645
# [78]	train-rmse:0.177184	eval-rmse:0.62449
# [79]	train-rmse:0.175559	eval-rmse:0.624541
# [80]	train-rmse:0.171581	eval-rmse:0.624708
# [81]	train-rmse:0.167201	eval-rmse:0.624754
# [82]	train-rmse:0.165172	eval-rmse:0.623849
# [83]	train-rmse:0.162532	eval-rmse:0.623609
# [84]	train-rmse:0.160821	eval-rmse:0.623138
# [85]	train-rmse:0.159325	eval-rmse:0.622944
# [86]	train-rmse:0.157592	eval-rmse:0.622937
# [87]	train-rmse:0.155403	eval-rmse:0.622877
# [88]	train-rmse:0.153687	eval-rmse:0.622626
# [89]	train-rmse:0.150414	eval-rmse:0.622357
# [90]	train-rmse:0.148352	eval-rmse:0.622117
# [91]	train-rmse:0.147052	eval-rmse:0.622118
# [92]	train-rmse:0.146389	eval-rmse:0.621944
# [93]	train-rmse:0.14448	eval-rmse:0.621734
# [94]	train-rmse:0.143438	eval-rmse:0.621679
# [95]	train-rmse:0.141676	eval-rmse:0.621614
# [96]	train-rmse:0.140063	eval-rmse:0.621443
# [97]	train-rmse:0.139415	eval-rmse:0.621502
# [98]	train-rmse:0.138886	eval-rmse:0.6217
# [99]	train-rmse:0.137635	eval-rmse:0.621712
# [100]	train-rmse:0.135531	eval-rmse:0.621451
# [101]	train-rmse:0.134154	eval-rmse:0.621145
# [102]	train-rmse:0.133047	eval-rmse:0.621112
# [103]	train-rmse:0.131429	eval-rmse:0.621097
# [104]	train-rmse:0.13051	eval-rmse:0.620881
# [105]	train-rmse:0.129053	eval-rmse:0.620878
# [106]	train-rmse:0.128543	eval-rmse:0.62086
# [107]	train-rmse:0.127325	eval-rmse:0.621097
# [108]	train-rmse:0.125862	eval-rmse:0.621368
# [109]	train-rmse:0.125	eval-rmse:0.621122
# [110]	train-rmse:0.123728	eval-rmse:0.621046
# [111]	train-rmse:0.122518	eval-rmse:0.620775
# [112]	train-rmse:0.121407	eval-rmse:0.620597
# [113]	train-rmse:0.121084	eval-rmse:0.620556
# [114]	train-rmse:0.119997	eval-rmse:0.620755
# [115]	train-rmse:0.119004	eval-rmse:0.620487
# [116]	train-rmse:0.117882	eval-rmse:0.620546
# [117]	train-rmse:0.115775	eval-rmse:0.620079
# [118]	train-rmse:0.114763	eval-rmse:0.620236
# [119]	train-rmse:0.113763	eval-rmse:0.620578
# [120]	train-rmse:0.112759	eval-rmse:0.620566
# [121]	train-rmse:0.111847	eval-rmse:0.620513
# [122]	train-rmse:0.11095	eval-rmse:0.620725
# [123]	train-rmse:0.109437	eval-rmse:0.620221
# [124]	train-rmse:0.108218	eval-rmse:0.620093
# [125]	train-rmse:0.107331	eval-rmse:0.620233
# [126]	train-rmse:0.106335	eval-rmse:0.620096
# [127]	train-rmse:0.105193	eval-rmse:0.620179
# [128]	train-rmse:0.103743	eval-rmse:0.619757
# [129]	train-rmse:0.102367	eval-rmse:0.619651
# [130]	train-rmse:0.101287	eval-rmse:0.620053
# [131]	train-rmse:0.100204	eval-rmse:0.620027
# [132]	train-rmse:0.099054	eval-rmse:0.62006
# [133]	train-rmse:0.09862	eval-rmse:0.620034
# [134]	train-rmse:0.096828	eval-rmse:0.620087
# [135]	train-rmse:0.096326	eval-rmse:0.619996
# [136]	train-rmse:0.095766	eval-rmse:0.619894
# [137]	train-rmse:0.094175	eval-rmse:0.619578
# [138]	train-rmse:0.093446	eval-rmse:0.619457
# [139]	train-rmse:0.092766	eval-rmse:0.619608
# [140]	train-rmse:0.091733	eval-rmse:0.61975
# [141]	train-rmse:0.090148	eval-rmse:0.619976
# [142]	train-rmse:0.08875	eval-rmse:0.619875
# [143]	train-rmse:0.087749	eval-rmse:0.61968
# [144]	train-rmse:0.08665	eval-rmse:0.619746
# [145]	train-rmse:0.085477	eval-rmse:0.619647
# [146]	train-rmse:0.085177	eval-rmse:0.619811
# [147]	train-rmse:0.084503	eval-rmse:0.619796
# [148]	train-rmse:0.084004	eval-rmse:0.619705
# [149]	train-rmse:0.083604	eval-rmse:0.619688
# [150]	train-rmse:0.083304	eval-rmse:0.61971
# [151]	train-rmse:0.082543	eval-rmse:0.619756
# [152]	train-rmse:0.081962	eval-rmse:0.619559
# [153]	train-rmse:0.081501	eval-rmse:0.619523
# [154]	train-rmse:0.081065	eval-rmse:0.619603
# [155]	train-rmse:0.080187	eval-rmse:0.619694
# [156]	train-rmse:0.079882	eval-rmse:0.619609
# [157]	train-rmse:0.079599	eval-rmse:0.619703
# [158]	train-rmse:0.078496	eval-rmse:0.619847
# Stopping. Best iteration:
# [138]	train-rmse:0.093446	eval-rmse:0.619457
#
# mean_squared_log_error: 0.6198464632388957
# save model: models/xgb_fold1.pkl
# ==================================================
# fold: 2
# [0]	train-rmse:6.3453	eval-rmse:6.32314
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.48032	eval-rmse:4.46271
# [2]	train-rmse:3.18289	eval-rmse:3.17071
# [3]	train-rmse:2.28546	eval-rmse:2.27935
# [4]	train-rmse:1.66842	eval-rmse:1.67336
# [5]	train-rmse:1.25345	eval-rmse:1.2749
# [6]	train-rmse:0.979531	eval-rmse:1.0157
# [7]	train-rmse:0.803565	eval-rmse:0.856534
# [8]	train-rmse:0.687954	eval-rmse:0.76619
# [9]	train-rmse:0.621318	eval-rmse:0.715725
# [10]	train-rmse:0.583855	eval-rmse:0.688909
# [11]	train-rmse:0.552471	eval-rmse:0.672155
# [12]	train-rmse:0.529425	eval-rmse:0.660758
# [13]	train-rmse:0.512126	eval-rmse:0.654959
# [14]	train-rmse:0.498266	eval-rmse:0.651404
# [15]	train-rmse:0.480536	eval-rmse:0.644943
# [16]	train-rmse:0.469285	eval-rmse:0.641994
# [17]	train-rmse:0.456601	eval-rmse:0.639695
# [18]	train-rmse:0.447134	eval-rmse:0.638598
# [19]	train-rmse:0.435498	eval-rmse:0.634173
# [20]	train-rmse:0.429834	eval-rmse:0.632553
# [21]	train-rmse:0.418318	eval-rmse:0.630774
# [22]	train-rmse:0.407558	eval-rmse:0.628084
# [23]	train-rmse:0.395103	eval-rmse:0.625869
# [24]	train-rmse:0.386282	eval-rmse:0.622947
# [25]	train-rmse:0.381645	eval-rmse:0.622092
# [26]	train-rmse:0.373724	eval-rmse:0.621266
# [27]	train-rmse:0.36789	eval-rmse:0.619891
# [28]	train-rmse:0.363438	eval-rmse:0.619242
# [29]	train-rmse:0.355271	eval-rmse:0.616177
# [30]	train-rmse:0.349596	eval-rmse:0.61536
# [31]	train-rmse:0.343216	eval-rmse:0.615021
# [32]	train-rmse:0.33765	eval-rmse:0.61393
# [33]	train-rmse:0.330958	eval-rmse:0.613078
# [34]	train-rmse:0.326929	eval-rmse:0.61225
# [35]	train-rmse:0.322807	eval-rmse:0.612118
# [36]	train-rmse:0.319879	eval-rmse:0.611589
# [37]	train-rmse:0.310234	eval-rmse:0.60796
# [38]	train-rmse:0.305941	eval-rmse:0.606872
# [39]	train-rmse:0.301466	eval-rmse:0.605911
# [40]	train-rmse:0.297934	eval-rmse:0.605607
# [41]	train-rmse:0.292302	eval-rmse:0.605866
# [42]	train-rmse:0.285151	eval-rmse:0.605335
# [43]	train-rmse:0.282741	eval-rmse:0.604868
# [44]	train-rmse:0.278014	eval-rmse:0.604911
# [45]	train-rmse:0.273976	eval-rmse:0.605206
# [46]	train-rmse:0.271271	eval-rmse:0.605149
# [47]	train-rmse:0.267317	eval-rmse:0.605414
# [48]	train-rmse:0.264127	eval-rmse:0.604939
# [49]	train-rmse:0.261771	eval-rmse:0.604012
# [50]	train-rmse:0.259186	eval-rmse:0.604168
# [51]	train-rmse:0.254492	eval-rmse:0.603042
# [52]	train-rmse:0.250324	eval-rmse:0.602971
# [53]	train-rmse:0.246556	eval-rmse:0.603492
# [54]	train-rmse:0.244712	eval-rmse:0.60336
# [55]	train-rmse:0.241045	eval-rmse:0.603363
# [56]	train-rmse:0.238497	eval-rmse:0.603156
# [57]	train-rmse:0.233755	eval-rmse:0.601568
# [58]	train-rmse:0.228889	eval-rmse:0.601484
# [59]	train-rmse:0.223518	eval-rmse:0.60102
# [60]	train-rmse:0.2218	eval-rmse:0.600756
# [61]	train-rmse:0.219093	eval-rmse:0.600745
# [62]	train-rmse:0.215402	eval-rmse:0.600872
# [63]	train-rmse:0.213845	eval-rmse:0.600715
# [64]	train-rmse:0.212148	eval-rmse:0.601022
# [65]	train-rmse:0.209965	eval-rmse:0.600778
# [66]	train-rmse:0.206534	eval-rmse:0.600707
# [67]	train-rmse:0.204081	eval-rmse:0.5999
# [68]	train-rmse:0.200133	eval-rmse:0.599845
# [69]	train-rmse:0.196221	eval-rmse:0.598958
# [70]	train-rmse:0.193094	eval-rmse:0.598827
# [71]	train-rmse:0.189133	eval-rmse:0.598301
# [72]	train-rmse:0.187917	eval-rmse:0.598028
# [73]	train-rmse:0.184849	eval-rmse:0.598118
# [74]	train-rmse:0.182552	eval-rmse:0.597289
# [75]	train-rmse:0.181053	eval-rmse:0.596928
# [76]	train-rmse:0.178236	eval-rmse:0.597029
# [77]	train-rmse:0.176035	eval-rmse:0.596513
# [78]	train-rmse:0.173924	eval-rmse:0.596269
# [79]	train-rmse:0.172337	eval-rmse:0.596539
# [80]	train-rmse:0.170196	eval-rmse:0.596625
# [81]	train-rmse:0.167066	eval-rmse:0.596893
# [82]	train-rmse:0.164101	eval-rmse:0.596308
# [83]	train-rmse:0.162992	eval-rmse:0.596472
# [84]	train-rmse:0.159285	eval-rmse:0.596274
# [85]	train-rmse:0.158065	eval-rmse:0.596075
# [86]	train-rmse:0.155782	eval-rmse:0.596164
# [87]	train-rmse:0.154883	eval-rmse:0.596019
# [88]	train-rmse:0.154376	eval-rmse:0.595933
# [89]	train-rmse:0.153292	eval-rmse:0.595537
# [90]	train-rmse:0.15229	eval-rmse:0.595297
# [91]	train-rmse:0.150075	eval-rmse:0.595451
# [92]	train-rmse:0.14887	eval-rmse:0.595203
# [93]	train-rmse:0.146638	eval-rmse:0.595262
# [94]	train-rmse:0.144192	eval-rmse:0.594888
# [95]	train-rmse:0.142729	eval-rmse:0.594655
# [96]	train-rmse:0.140088	eval-rmse:0.594516
# [97]	train-rmse:0.137555	eval-rmse:0.594361
# [98]	train-rmse:0.136249	eval-rmse:0.594247
# [99]	train-rmse:0.1351	eval-rmse:0.594119
# [100]	train-rmse:0.132472	eval-rmse:0.593793
# [101]	train-rmse:0.130693	eval-rmse:0.593554
# [102]	train-rmse:0.129528	eval-rmse:0.593601
# [103]	train-rmse:0.127965	eval-rmse:0.593529
# [104]	train-rmse:0.126794	eval-rmse:0.593394
# [105]	train-rmse:0.124819	eval-rmse:0.592765
# [106]	train-rmse:0.122539	eval-rmse:0.592591
# [107]	train-rmse:0.121352	eval-rmse:0.592297
# [108]	train-rmse:0.120167	eval-rmse:0.592204
# [109]	train-rmse:0.11912	eval-rmse:0.5921
# [110]	train-rmse:0.118161	eval-rmse:0.591867
# [111]	train-rmse:0.116433	eval-rmse:0.591857
# [112]	train-rmse:0.115214	eval-rmse:0.591871
# [113]	train-rmse:0.114222	eval-rmse:0.591653
# [114]	train-rmse:0.113392	eval-rmse:0.591771
# [115]	train-rmse:0.112299	eval-rmse:0.59151
# [116]	train-rmse:0.111369	eval-rmse:0.591647
# [117]	train-rmse:0.110838	eval-rmse:0.591578
# [118]	train-rmse:0.108798	eval-rmse:0.591319
# [119]	train-rmse:0.107499	eval-rmse:0.591249
# [120]	train-rmse:0.10662	eval-rmse:0.591245
# [121]	train-rmse:0.105975	eval-rmse:0.59129
# [122]	train-rmse:0.104629	eval-rmse:0.591112
# [123]	train-rmse:0.103515	eval-rmse:0.591082
# [124]	train-rmse:0.102377	eval-rmse:0.591152
# [125]	train-rmse:0.101495	eval-rmse:0.591034
# [126]	train-rmse:0.099959	eval-rmse:0.590858
# [127]	train-rmse:0.099276	eval-rmse:0.591138
# [128]	train-rmse:0.098988	eval-rmse:0.591105
# [129]	train-rmse:0.097898	eval-rmse:0.59116
# [130]	train-rmse:0.096894	eval-rmse:0.59091
# [131]	train-rmse:0.095707	eval-rmse:0.590729
# [132]	train-rmse:0.094657	eval-rmse:0.59067
# [133]	train-rmse:0.094352	eval-rmse:0.59079
# [134]	train-rmse:0.093945	eval-rmse:0.590885
# [135]	train-rmse:0.093023	eval-rmse:0.590593
# [136]	train-rmse:0.091933	eval-rmse:0.590525
# [137]	train-rmse:0.091248	eval-rmse:0.59058
# [138]	train-rmse:0.090631	eval-rmse:0.590548
# [139]	train-rmse:0.090398	eval-rmse:0.590446
# [140]	train-rmse:0.089733	eval-rmse:0.590263
# [141]	train-rmse:0.089184	eval-rmse:0.590571
# [142]	train-rmse:0.087964	eval-rmse:0.59074
# [143]	train-rmse:0.087144	eval-rmse:0.590759
# [144]	train-rmse:0.086649	eval-rmse:0.590723
# [145]	train-rmse:0.08528	eval-rmse:0.590575
# [146]	train-rmse:0.084614	eval-rmse:0.590476
# [147]	train-rmse:0.084282	eval-rmse:0.590375
# [148]	train-rmse:0.083718	eval-rmse:0.590318
# [149]	train-rmse:0.082615	eval-rmse:0.590197
# [150]	train-rmse:0.081886	eval-rmse:0.590281
# [151]	train-rmse:0.081349	eval-rmse:0.590276
# [152]	train-rmse:0.080737	eval-rmse:0.590287
# [153]	train-rmse:0.079646	eval-rmse:0.590115
# [154]	train-rmse:0.079194	eval-rmse:0.590073
# [155]	train-rmse:0.079008	eval-rmse:0.59006
# [156]	train-rmse:0.078869	eval-rmse:0.59009
# [157]	train-rmse:0.078674	eval-rmse:0.590044
# [158]	train-rmse:0.07854	eval-rmse:0.590086
# [159]	train-rmse:0.077905	eval-rmse:0.589758
# [160]	train-rmse:0.077373	eval-rmse:0.589778
# [161]	train-rmse:0.076561	eval-rmse:0.589832
# [162]	train-rmse:0.075684	eval-rmse:0.589821
# [163]	train-rmse:0.074548	eval-rmse:0.589582
# [164]	train-rmse:0.073817	eval-rmse:0.589912
# [165]	train-rmse:0.073183	eval-rmse:0.589775
# [166]	train-rmse:0.072609	eval-rmse:0.589828
# [167]	train-rmse:0.071723	eval-rmse:0.590084
# [168]	train-rmse:0.070949	eval-rmse:0.590014
# [169]	train-rmse:0.070683	eval-rmse:0.590014
# [170]	train-rmse:0.07037	eval-rmse:0.589918
# [171]	train-rmse:0.06989	eval-rmse:0.589848
# [172]	train-rmse:0.069489	eval-rmse:0.589798
# [173]	train-rmse:0.069231	eval-rmse:0.589786
# [174]	train-rmse:0.068696	eval-rmse:0.589731
# [175]	train-rmse:0.068264	eval-rmse:0.589591
# [176]	train-rmse:0.067541	eval-rmse:0.589689
# [177]	train-rmse:0.06689	eval-rmse:0.589623
# [178]	train-rmse:0.066686	eval-rmse:0.589569
# [179]	train-rmse:0.066286	eval-rmse:0.589625
# [180]	train-rmse:0.065566	eval-rmse:0.589797
# [181]	train-rmse:0.065348	eval-rmse:0.589772
# [182]	train-rmse:0.0646	eval-rmse:0.589505
# [183]	train-rmse:0.064357	eval-rmse:0.589474
# [184]	train-rmse:0.063806	eval-rmse:0.589538
# [185]	train-rmse:0.063558	eval-rmse:0.589601
# [186]	train-rmse:0.063031	eval-rmse:0.589499
# [187]	train-rmse:0.062618	eval-rmse:0.58946
# [188]	train-rmse:0.061912	eval-rmse:0.589337
# [189]	train-rmse:0.060764	eval-rmse:0.589269
# [190]	train-rmse:0.060077	eval-rmse:0.589414
# [191]	train-rmse:0.05956	eval-rmse:0.589383
# [192]	train-rmse:0.059005	eval-rmse:0.589273
# [193]	train-rmse:0.058721	eval-rmse:0.589234
# [194]	train-rmse:0.058402	eval-rmse:0.589226
# [195]	train-rmse:0.058234	eval-rmse:0.58923
# [196]	train-rmse:0.057825	eval-rmse:0.58912
# [197]	train-rmse:0.057505	eval-rmse:0.589097
# [198]	train-rmse:0.056713	eval-rmse:0.589176
# [199]	train-rmse:0.056402	eval-rmse:0.58924
# mean_squared_log_error: 0.5892403150525567
# save model: models/xgb_fold2.pkl
# ==================================================
# fold: 3
# [0]	train-rmse:6.33658	eval-rmse:6.36999
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.47468	eval-rmse:4.51069
# [2]	train-rmse:3.17931	eval-rmse:3.21594
# [3]	train-rmse:2.28214	eval-rmse:2.32212
# [4]	train-rmse:1.67082	eval-rmse:1.71796
# [5]	train-rmse:1.25116	eval-rmse:1.31543
# [6]	train-rmse:0.972809	eval-rmse:1.05259
# [7]	train-rmse:0.793398	eval-rmse:0.887253
# [8]	train-rmse:0.682627	eval-rmse:0.792498
# [9]	train-rmse:0.612211	eval-rmse:0.736475
# [10]	train-rmse:0.564028	eval-rmse:0.702203
# [11]	train-rmse:0.52739	eval-rmse:0.680674
# [12]	train-rmse:0.507913	eval-rmse:0.669678
# [13]	train-rmse:0.487837	eval-rmse:0.657542
# [14]	train-rmse:0.474225	eval-rmse:0.654535
# [15]	train-rmse:0.45819	eval-rmse:0.650108
# [16]	train-rmse:0.446558	eval-rmse:0.647426
# [17]	train-rmse:0.436666	eval-rmse:0.642381
# [18]	train-rmse:0.417907	eval-rmse:0.637232
# [19]	train-rmse:0.410641	eval-rmse:0.634663
# [20]	train-rmse:0.400444	eval-rmse:0.631131
# [21]	train-rmse:0.389169	eval-rmse:0.629418
# [22]	train-rmse:0.380222	eval-rmse:0.628251
# [23]	train-rmse:0.375457	eval-rmse:0.62738
# [24]	train-rmse:0.36965	eval-rmse:0.625448
# [25]	train-rmse:0.358788	eval-rmse:0.626289
# [26]	train-rmse:0.352839	eval-rmse:0.624952
# [27]	train-rmse:0.342958	eval-rmse:0.622944
# [28]	train-rmse:0.336132	eval-rmse:0.621046
# [29]	train-rmse:0.332508	eval-rmse:0.620827
# [30]	train-rmse:0.323327	eval-rmse:0.620939
# [31]	train-rmse:0.317647	eval-rmse:0.619447
# [32]	train-rmse:0.313046	eval-rmse:0.617826
# [33]	train-rmse:0.310694	eval-rmse:0.617692
# [34]	train-rmse:0.30551	eval-rmse:0.616951
# [35]	train-rmse:0.302788	eval-rmse:0.616258
# [36]	train-rmse:0.295984	eval-rmse:0.615682
# [37]	train-rmse:0.288592	eval-rmse:0.615832
# [38]	train-rmse:0.286618	eval-rmse:0.615776
# [39]	train-rmse:0.281684	eval-rmse:0.614851
# [40]	train-rmse:0.277349	eval-rmse:0.614375
# [41]	train-rmse:0.274291	eval-rmse:0.614353
# [42]	train-rmse:0.269796	eval-rmse:0.613623
# [43]	train-rmse:0.265561	eval-rmse:0.612912
# [44]	train-rmse:0.259054	eval-rmse:0.612447
# [45]	train-rmse:0.255056	eval-rmse:0.612
# [46]	train-rmse:0.251234	eval-rmse:0.610823
# [47]	train-rmse:0.247282	eval-rmse:0.609871
# [48]	train-rmse:0.242253	eval-rmse:0.608416
# [49]	train-rmse:0.237525	eval-rmse:0.607224
# [50]	train-rmse:0.234102	eval-rmse:0.60702
# [51]	train-rmse:0.232549	eval-rmse:0.607361
# [52]	train-rmse:0.23097	eval-rmse:0.607314
# [53]	train-rmse:0.226119	eval-rmse:0.605898
# [54]	train-rmse:0.224464	eval-rmse:0.605307
# [55]	train-rmse:0.222258	eval-rmse:0.604533
# [56]	train-rmse:0.220548	eval-rmse:0.604317
# [57]	train-rmse:0.219218	eval-rmse:0.604247
# [58]	train-rmse:0.218043	eval-rmse:0.604054
# [59]	train-rmse:0.214807	eval-rmse:0.603831
# [60]	train-rmse:0.211447	eval-rmse:0.603598
# [61]	train-rmse:0.208573	eval-rmse:0.603183
# [62]	train-rmse:0.205803	eval-rmse:0.60281
# [63]	train-rmse:0.201986	eval-rmse:0.60257
# [64]	train-rmse:0.198279	eval-rmse:0.60198
# [65]	train-rmse:0.195408	eval-rmse:0.600964
# [66]	train-rmse:0.193634	eval-rmse:0.599406
# [67]	train-rmse:0.189645	eval-rmse:0.599203
# [68]	train-rmse:0.187815	eval-rmse:0.599033
# [69]	train-rmse:0.183627	eval-rmse:0.598743
# [70]	train-rmse:0.181553	eval-rmse:0.598551
# [71]	train-rmse:0.180786	eval-rmse:0.598709
# [72]	train-rmse:0.177306	eval-rmse:0.598642
# [73]	train-rmse:0.175179	eval-rmse:0.598881
# [74]	train-rmse:0.17293	eval-rmse:0.598803
# [75]	train-rmse:0.171439	eval-rmse:0.599051
# [76]	train-rmse:0.168998	eval-rmse:0.598877
# [77]	train-rmse:0.16594	eval-rmse:0.598586
# [78]	train-rmse:0.165109	eval-rmse:0.598759
# [79]	train-rmse:0.163708	eval-rmse:0.598449
# [80]	train-rmse:0.162285	eval-rmse:0.598372
# [81]	train-rmse:0.160323	eval-rmse:0.598156
# [82]	train-rmse:0.158272	eval-rmse:0.597957
# [83]	train-rmse:0.156369	eval-rmse:0.597915
# [84]	train-rmse:0.155038	eval-rmse:0.597669
# [85]	train-rmse:0.152859	eval-rmse:0.59748
# [86]	train-rmse:0.15243	eval-rmse:0.597392
# [87]	train-rmse:0.150342	eval-rmse:0.596866
# [88]	train-rmse:0.149327	eval-rmse:0.597027
# [89]	train-rmse:0.146639	eval-rmse:0.596248
# [90]	train-rmse:0.144106	eval-rmse:0.596216
# [91]	train-rmse:0.142255	eval-rmse:0.596295
# [92]	train-rmse:0.140678	eval-rmse:0.596029
# [93]	train-rmse:0.138726	eval-rmse:0.595941
# [94]	train-rmse:0.137793	eval-rmse:0.596044
# [95]	train-rmse:0.137235	eval-rmse:0.596003
# [96]	train-rmse:0.136157	eval-rmse:0.595805
# [97]	train-rmse:0.13452	eval-rmse:0.595511
# [98]	train-rmse:0.133924	eval-rmse:0.595502
# [99]	train-rmse:0.132289	eval-rmse:0.5952
# [100]	train-rmse:0.131372	eval-rmse:0.595252
# [101]	train-rmse:0.12987	eval-rmse:0.595338
# [102]	train-rmse:0.127683	eval-rmse:0.595039
# [103]	train-rmse:0.126279	eval-rmse:0.594931
# [104]	train-rmse:0.124089	eval-rmse:0.594893
# [105]	train-rmse:0.122389	eval-rmse:0.594766
# [106]	train-rmse:0.120845	eval-rmse:0.594964
# [107]	train-rmse:0.119937	eval-rmse:0.594659
# [108]	train-rmse:0.119344	eval-rmse:0.59457
# [109]	train-rmse:0.11791	eval-rmse:0.59444
# [110]	train-rmse:0.116984	eval-rmse:0.594284
# [111]	train-rmse:0.11569	eval-rmse:0.594237
# [112]	train-rmse:0.114414	eval-rmse:0.594303
# [113]	train-rmse:0.113617	eval-rmse:0.59428
# [114]	train-rmse:0.112958	eval-rmse:0.594041
# [115]	train-rmse:0.111839	eval-rmse:0.593675
# [116]	train-rmse:0.110697	eval-rmse:0.5935
# [117]	train-rmse:0.109345	eval-rmse:0.593275
# [118]	train-rmse:0.108694	eval-rmse:0.59329
# [119]	train-rmse:0.107842	eval-rmse:0.593105
# [120]	train-rmse:0.107497	eval-rmse:0.593086
# [121]	train-rmse:0.105265	eval-rmse:0.593183
# [122]	train-rmse:0.104738	eval-rmse:0.593354
# [123]	train-rmse:0.103667	eval-rmse:0.593369
# [124]	train-rmse:0.103357	eval-rmse:0.593344
# [125]	train-rmse:0.102483	eval-rmse:0.593297
# [126]	train-rmse:0.101823	eval-rmse:0.593072
# [127]	train-rmse:0.100445	eval-rmse:0.593015
# [128]	train-rmse:0.099834	eval-rmse:0.593017
# [129]	train-rmse:0.098767	eval-rmse:0.593055
# [130]	train-rmse:0.097611	eval-rmse:0.592827
# [131]	train-rmse:0.096119	eval-rmse:0.592937
# [132]	train-rmse:0.095197	eval-rmse:0.59294
# [133]	train-rmse:0.094789	eval-rmse:0.592896
# [134]	train-rmse:0.093118	eval-rmse:0.592959
# [135]	train-rmse:0.091931	eval-rmse:0.592655
# [136]	train-rmse:0.091456	eval-rmse:0.592651
# [137]	train-rmse:0.089737	eval-rmse:0.592741
# [138]	train-rmse:0.089099	eval-rmse:0.592556
# [139]	train-rmse:0.088362	eval-rmse:0.592644
# [140]	train-rmse:0.087692	eval-rmse:0.592762
# [141]	train-rmse:0.086889	eval-rmse:0.592678
# [142]	train-rmse:0.085465	eval-rmse:0.59254
# [143]	train-rmse:0.084975	eval-rmse:0.592521
# [144]	train-rmse:0.083893	eval-rmse:0.592507
# [145]	train-rmse:0.082459	eval-rmse:0.592688
# [146]	train-rmse:0.081956	eval-rmse:0.592712
# [147]	train-rmse:0.081396	eval-rmse:0.592677
# [148]	train-rmse:0.080622	eval-rmse:0.592757
# [149]	train-rmse:0.079592	eval-rmse:0.592597
# [150]	train-rmse:0.07903	eval-rmse:0.592387
# [151]	train-rmse:0.078755	eval-rmse:0.592359
# [152]	train-rmse:0.077957	eval-rmse:0.592544
# [153]	train-rmse:0.077275	eval-rmse:0.59275
# [154]	train-rmse:0.077092	eval-rmse:0.592839
# [155]	train-rmse:0.076112	eval-rmse:0.592686
# [156]	train-rmse:0.075846	eval-rmse:0.592583
# [157]	train-rmse:0.075336	eval-rmse:0.592603
# [158]	train-rmse:0.074378	eval-rmse:0.592567
# [159]	train-rmse:0.074127	eval-rmse:0.592542
# [160]	train-rmse:0.073261	eval-rmse:0.59239
# [161]	train-rmse:0.072492	eval-rmse:0.592337
# [162]	train-rmse:0.072161	eval-rmse:0.592281
# [163]	train-rmse:0.07126	eval-rmse:0.592305
# [164]	train-rmse:0.07099	eval-rmse:0.592177
# [165]	train-rmse:0.070403	eval-rmse:0.59204
# [166]	train-rmse:0.06973	eval-rmse:0.59194
# [167]	train-rmse:0.069385	eval-rmse:0.592001
# [168]	train-rmse:0.069125	eval-rmse:0.592028
# [169]	train-rmse:0.068608	eval-rmse:0.591972
# [170]	train-rmse:0.068253	eval-rmse:0.591871
# [171]	train-rmse:0.067782	eval-rmse:0.591784
# [172]	train-rmse:0.067335	eval-rmse:0.591746
# [173]	train-rmse:0.066492	eval-rmse:0.591739
# [174]	train-rmse:0.065826	eval-rmse:0.591699
# [175]	train-rmse:0.065231	eval-rmse:0.591744
# [176]	train-rmse:0.064529	eval-rmse:0.591893
# [177]	train-rmse:0.064188	eval-rmse:0.591994
# [178]	train-rmse:0.063619	eval-rmse:0.591898
# [179]	train-rmse:0.062794	eval-rmse:0.591869
# [180]	train-rmse:0.061988	eval-rmse:0.591929
# [181]	train-rmse:0.061382	eval-rmse:0.591862
# [182]	train-rmse:0.060856	eval-rmse:0.591857
# [183]	train-rmse:0.060382	eval-rmse:0.591882
# [184]	train-rmse:0.059905	eval-rmse:0.591801
# [185]	train-rmse:0.059614	eval-rmse:0.591786
# [186]	train-rmse:0.059407	eval-rmse:0.591799
# [187]	train-rmse:0.059117	eval-rmse:0.591708
# [188]	train-rmse:0.058838	eval-rmse:0.591789
# [189]	train-rmse:0.058652	eval-rmse:0.591768
# [190]	train-rmse:0.058146	eval-rmse:0.591707
# [191]	train-rmse:0.057772	eval-rmse:0.591763
# [192]	train-rmse:0.057544	eval-rmse:0.591794
# [193]	train-rmse:0.057283	eval-rmse:0.591773
# [194]	train-rmse:0.056889	eval-rmse:0.591756
# Stopping. Best iteration:
# [174]	train-rmse:0.065826	eval-rmse:0.591699
#
# mean_squared_log_error: 0.591755719059794
# save model: models/xgb_fold3.pkl
# ==================================================
# fold: 4
# [0]	train-rmse:6.34529	eval-rmse:6.32415
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.48051	eval-rmse:4.46675
# [2]	train-rmse:3.18357	eval-rmse:3.17462
# [3]	train-rmse:2.28641	eval-rmse:2.28192
# [4]	train-rmse:1.67266	eval-rmse:1.67772
# [5]	train-rmse:1.25506	eval-rmse:1.27307
# [6]	train-rmse:0.975444	eval-rmse:1.00814
# [7]	train-rmse:0.802151	eval-rmse:0.849383
# [8]	train-rmse:0.693514	eval-rmse:0.755891
# [9]	train-rmse:0.61874	eval-rmse:0.69628
# [10]	train-rmse:0.57836	eval-rmse:0.668427
# [11]	train-rmse:0.545183	eval-rmse:0.650172
# [12]	train-rmse:0.516356	eval-rmse:0.636282
# [13]	train-rmse:0.492879	eval-rmse:0.627555
# [14]	train-rmse:0.472099	eval-rmse:0.623061
# [15]	train-rmse:0.45705	eval-rmse:0.617594
# [16]	train-rmse:0.446469	eval-rmse:0.612927
# [17]	train-rmse:0.435232	eval-rmse:0.610578
# [18]	train-rmse:0.427668	eval-rmse:0.608429
# [19]	train-rmse:0.415636	eval-rmse:0.60705
# [20]	train-rmse:0.408861	eval-rmse:0.60539
# [21]	train-rmse:0.401031	eval-rmse:0.604959
# [22]	train-rmse:0.392724	eval-rmse:0.603063
# [23]	train-rmse:0.385892	eval-rmse:0.601167
# [24]	train-rmse:0.379965	eval-rmse:0.599404
# [25]	train-rmse:0.369239	eval-rmse:0.599008
# [26]	train-rmse:0.362168	eval-rmse:0.596917
# [27]	train-rmse:0.354767	eval-rmse:0.596709
# [28]	train-rmse:0.349761	eval-rmse:0.596678
# [29]	train-rmse:0.34247	eval-rmse:0.596145
# [30]	train-rmse:0.337924	eval-rmse:0.594791
# [31]	train-rmse:0.331703	eval-rmse:0.593698
# [32]	train-rmse:0.326606	eval-rmse:0.591816
# [33]	train-rmse:0.321672	eval-rmse:0.591523
# [34]	train-rmse:0.318204	eval-rmse:0.590415
# [35]	train-rmse:0.31364	eval-rmse:0.59008
# [36]	train-rmse:0.31003	eval-rmse:0.589128
# [37]	train-rmse:0.303827	eval-rmse:0.587815
# [38]	train-rmse:0.297291	eval-rmse:0.587113
# [39]	train-rmse:0.292442	eval-rmse:0.585706
# [40]	train-rmse:0.284983	eval-rmse:0.584037
# [41]	train-rmse:0.280454	eval-rmse:0.583723
# [42]	train-rmse:0.273634	eval-rmse:0.581871
# [43]	train-rmse:0.268238	eval-rmse:0.581136
# [44]	train-rmse:0.263549	eval-rmse:0.58056
# [45]	train-rmse:0.262226	eval-rmse:0.579981
# [46]	train-rmse:0.256232	eval-rmse:0.579502
# [47]	train-rmse:0.253192	eval-rmse:0.579174
# [48]	train-rmse:0.247878	eval-rmse:0.578573
# [49]	train-rmse:0.245369	eval-rmse:0.578498
# [50]	train-rmse:0.241825	eval-rmse:0.57761
# [51]	train-rmse:0.238622	eval-rmse:0.577735
# [52]	train-rmse:0.235764	eval-rmse:0.57747
# [53]	train-rmse:0.234101	eval-rmse:0.577247
# [54]	train-rmse:0.231967	eval-rmse:0.576755
# [55]	train-rmse:0.22755	eval-rmse:0.576255
# [56]	train-rmse:0.224753	eval-rmse:0.576139
# [57]	train-rmse:0.223165	eval-rmse:0.576285
# [58]	train-rmse:0.218829	eval-rmse:0.575805
# [59]	train-rmse:0.2166	eval-rmse:0.575583
# [60]	train-rmse:0.21358	eval-rmse:0.57559
# [61]	train-rmse:0.211135	eval-rmse:0.575628
# [62]	train-rmse:0.207637	eval-rmse:0.574463
# [63]	train-rmse:0.202991	eval-rmse:0.57368
# [64]	train-rmse:0.200354	eval-rmse:0.57365
# [65]	train-rmse:0.199584	eval-rmse:0.573571
# [66]	train-rmse:0.198072	eval-rmse:0.573637
# [67]	train-rmse:0.195033	eval-rmse:0.57355
# [68]	train-rmse:0.192444	eval-rmse:0.573634
# [69]	train-rmse:0.189665	eval-rmse:0.573585
# [70]	train-rmse:0.18854	eval-rmse:0.573339
# [71]	train-rmse:0.187608	eval-rmse:0.573337
# [72]	train-rmse:0.185575	eval-rmse:0.572981
# [73]	train-rmse:0.18408	eval-rmse:0.572879
# [74]	train-rmse:0.181696	eval-rmse:0.573055
# [75]	train-rmse:0.179755	eval-rmse:0.572595
# [76]	train-rmse:0.177678	eval-rmse:0.572193
# [77]	train-rmse:0.174491	eval-rmse:0.572473
# [78]	train-rmse:0.172007	eval-rmse:0.572766
# [79]	train-rmse:0.168922	eval-rmse:0.57284
# [80]	train-rmse:0.164897	eval-rmse:0.572699
# [81]	train-rmse:0.161454	eval-rmse:0.57235
# [82]	train-rmse:0.158927	eval-rmse:0.572177
# [83]	train-rmse:0.15773	eval-rmse:0.572217
# [84]	train-rmse:0.15672	eval-rmse:0.572358
# [85]	train-rmse:0.156069	eval-rmse:0.572621
# [86]	train-rmse:0.153424	eval-rmse:0.573052
# [87]	train-rmse:0.151136	eval-rmse:0.573008
# [88]	train-rmse:0.149227	eval-rmse:0.573055
# [89]	train-rmse:0.148453	eval-rmse:0.573029
# [90]	train-rmse:0.14581	eval-rmse:0.572914
# [91]	train-rmse:0.144841	eval-rmse:0.572872
# [92]	train-rmse:0.143423	eval-rmse:0.572968
# [93]	train-rmse:0.141729	eval-rmse:0.572926
# [94]	train-rmse:0.140423	eval-rmse:0.572936
# [95]	train-rmse:0.139019	eval-rmse:0.572832
# [96]	train-rmse:0.136465	eval-rmse:0.572743
# [97]	train-rmse:0.134292	eval-rmse:0.572856
# [98]	train-rmse:0.13268	eval-rmse:0.572711
# [99]	train-rmse:0.131797	eval-rmse:0.572507
# [100]	train-rmse:0.130446	eval-rmse:0.572517
# [101]	train-rmse:0.129725	eval-rmse:0.572466
# [102]	train-rmse:0.127982	eval-rmse:0.572434
# Stopping. Best iteration:
# [82]	train-rmse:0.158927	eval-rmse:0.572177
#
# mean_squared_log_error: 0.5724341150114932
# save model: models/xgb_fold4.pkl
# ==================================================
# fold: 5
# [0]	train-rmse:6.34793	eval-rmse:6.30665
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:4.48217	eval-rmse:4.44313
# [2]	train-rmse:3.1847	eval-rmse:3.15078
# [3]	train-rmse:2.28469	eval-rmse:2.26309
# [4]	train-rmse:1.66902	eval-rmse:1.66002
# [5]	train-rmse:1.25497	eval-rmse:1.263
# [6]	train-rmse:0.980349	eval-rmse:1.01049
# [7]	train-rmse:0.802101	eval-rmse:0.862266
# [8]	train-rmse:0.687884	eval-rmse:0.766941
# [9]	train-rmse:0.614963	eval-rmse:0.716755
# [10]	train-rmse:0.571663	eval-rmse:0.685931
# [11]	train-rmse:0.537023	eval-rmse:0.6666
# [12]	train-rmse:0.516237	eval-rmse:0.659716
# [13]	train-rmse:0.494299	eval-rmse:0.645618
# [14]	train-rmse:0.476761	eval-rmse:0.641979
# [15]	train-rmse:0.462137	eval-rmse:0.636808
# [16]	train-rmse:0.449361	eval-rmse:0.634757
# [17]	train-rmse:0.440151	eval-rmse:0.634825
# [18]	train-rmse:0.431452	eval-rmse:0.6319
# [19]	train-rmse:0.425665	eval-rmse:0.630255
# [20]	train-rmse:0.412441	eval-rmse:0.625978
# [21]	train-rmse:0.403602	eval-rmse:0.625468
# [22]	train-rmse:0.401179	eval-rmse:0.625349
# [23]	train-rmse:0.386897	eval-rmse:0.621969
# [24]	train-rmse:0.378404	eval-rmse:0.619454
# [25]	train-rmse:0.371236	eval-rmse:0.617177
# [26]	train-rmse:0.36298	eval-rmse:0.615241
# [27]	train-rmse:0.36005	eval-rmse:0.614754
# [28]	train-rmse:0.355594	eval-rmse:0.612983
# [29]	train-rmse:0.353253	eval-rmse:0.612536
# [30]	train-rmse:0.340999	eval-rmse:0.611576
# [31]	train-rmse:0.335259	eval-rmse:0.610962
# [32]	train-rmse:0.330271	eval-rmse:0.609469
# [33]	train-rmse:0.324365	eval-rmse:0.607803
# [34]	train-rmse:0.318934	eval-rmse:0.606481
# [35]	train-rmse:0.312864	eval-rmse:0.606388
# [36]	train-rmse:0.306791	eval-rmse:0.605293
# [37]	train-rmse:0.301824	eval-rmse:0.605147
# [38]	train-rmse:0.296149	eval-rmse:0.604259
# [39]	train-rmse:0.292552	eval-rmse:0.603282
# [40]	train-rmse:0.286866	eval-rmse:0.602864
# [41]	train-rmse:0.281845	eval-rmse:0.602269
# [42]	train-rmse:0.278452	eval-rmse:0.602236
# [43]	train-rmse:0.274353	eval-rmse:0.601479
# [44]	train-rmse:0.270764	eval-rmse:0.600527
# [45]	train-rmse:0.26419	eval-rmse:0.599732
# [46]	train-rmse:0.259286	eval-rmse:0.598809
# [47]	train-rmse:0.256499	eval-rmse:0.598826
# [48]	train-rmse:0.254045	eval-rmse:0.598471
# [49]	train-rmse:0.250574	eval-rmse:0.598221
# [50]	train-rmse:0.248322	eval-rmse:0.597636
# [51]	train-rmse:0.244934	eval-rmse:0.59758
# [52]	train-rmse:0.240773	eval-rmse:0.596771
# [53]	train-rmse:0.235361	eval-rmse:0.596195
# [54]	train-rmse:0.231709	eval-rmse:0.5956
# [55]	train-rmse:0.231025	eval-rmse:0.59558
# [56]	train-rmse:0.228515	eval-rmse:0.595057
# [57]	train-rmse:0.225724	eval-rmse:0.594735
# [58]	train-rmse:0.221377	eval-rmse:0.593547
# [59]	train-rmse:0.216976	eval-rmse:0.593265
# [60]	train-rmse:0.213228	eval-rmse:0.592963
# [61]	train-rmse:0.209093	eval-rmse:0.592842
# [62]	train-rmse:0.207597	eval-rmse:0.593462
# [63]	train-rmse:0.205006	eval-rmse:0.593082
# [64]	train-rmse:0.201437	eval-rmse:0.592677
# [65]	train-rmse:0.199322	eval-rmse:0.592876
# [66]	train-rmse:0.198285	eval-rmse:0.593304
# [67]	train-rmse:0.195908	eval-rmse:0.593377
# [68]	train-rmse:0.193254	eval-rmse:0.59351
# [69]	train-rmse:0.190951	eval-rmse:0.593266
# [70]	train-rmse:0.188754	eval-rmse:0.593212
# [71]	train-rmse:0.18749	eval-rmse:0.593019
# [72]	train-rmse:0.18704	eval-rmse:0.593013
# [73]	train-rmse:0.185006	eval-rmse:0.592455
# [74]	train-rmse:0.184142	eval-rmse:0.592447
# [75]	train-rmse:0.182823	eval-rmse:0.592146
# [76]	train-rmse:0.180356	eval-rmse:0.591468
# [77]	train-rmse:0.178567	eval-rmse:0.591058
# [78]	train-rmse:0.175454	eval-rmse:0.590775
# [79]	train-rmse:0.173083	eval-rmse:0.590948
# [80]	train-rmse:0.17155	eval-rmse:0.590981
# [81]	train-rmse:0.169285	eval-rmse:0.591592
# [82]	train-rmse:0.166644	eval-rmse:0.591562
# [83]	train-rmse:0.16522	eval-rmse:0.59176
# [84]	train-rmse:0.163388	eval-rmse:0.591625
# [85]	train-rmse:0.161093	eval-rmse:0.591031
# [86]	train-rmse:0.158723	eval-rmse:0.590431
# [87]	train-rmse:0.155237	eval-rmse:0.590586
# [88]	train-rmse:0.154135	eval-rmse:0.590508
# [89]	train-rmse:0.152512	eval-rmse:0.590536
# [90]	train-rmse:0.150223	eval-rmse:0.59027
# [91]	train-rmse:0.147022	eval-rmse:0.589883
# [92]	train-rmse:0.145892	eval-rmse:0.58975
# [93]	train-rmse:0.144077	eval-rmse:0.588813
# [94]	train-rmse:0.142534	eval-rmse:0.58855
# [95]	train-rmse:0.140837	eval-rmse:0.588359
# [96]	train-rmse:0.139815	eval-rmse:0.588166
# [97]	train-rmse:0.137552	eval-rmse:0.588196
# [98]	train-rmse:0.136616	eval-rmse:0.588384
# [99]	train-rmse:0.134904	eval-rmse:0.588331
# [100]	train-rmse:0.133695	eval-rmse:0.588223
# [101]	train-rmse:0.133288	eval-rmse:0.58798
# [102]	train-rmse:0.131204	eval-rmse:0.587566
# [103]	train-rmse:0.129678	eval-rmse:0.587631
# [104]	train-rmse:0.12737	eval-rmse:0.58799
# [105]	train-rmse:0.126088	eval-rmse:0.588038
# [106]	train-rmse:0.12494	eval-rmse:0.588682
# [107]	train-rmse:0.123652	eval-rmse:0.588491
# [108]	train-rmse:0.122371	eval-rmse:0.58848
# [109]	train-rmse:0.121559	eval-rmse:0.588403
# [110]	train-rmse:0.120328	eval-rmse:0.588723
# [111]	train-rmse:0.118866	eval-rmse:0.588605
# [112]	train-rmse:0.118239	eval-rmse:0.588687
# [113]	train-rmse:0.116073	eval-rmse:0.588629
# [114]	train-rmse:0.115071	eval-rmse:0.58843
# [115]	train-rmse:0.11429	eval-rmse:0.588184
# [116]	train-rmse:0.113249	eval-rmse:0.588188
# [117]	train-rmse:0.112014	eval-rmse:0.588221
# [118]	train-rmse:0.110927	eval-rmse:0.588122
# [119]	train-rmse:0.108652	eval-rmse:0.587821
# [120]	train-rmse:0.107467	eval-rmse:0.587642
# [121]	train-rmse:0.106469	eval-rmse:0.587533
# [122]	train-rmse:0.104686	eval-rmse:0.58764
# [123]	train-rmse:0.104294	eval-rmse:0.587685
# [124]	train-rmse:0.103064	eval-rmse:0.587836
# [125]	train-rmse:0.101936	eval-rmse:0.587942
# [126]	train-rmse:0.100905	eval-rmse:0.587845
# [127]	train-rmse:0.100184	eval-rmse:0.58774
# [128]	train-rmse:0.09911	eval-rmse:0.587857
# [129]	train-rmse:0.097482	eval-rmse:0.588094
# [130]	train-rmse:0.096081	eval-rmse:0.588006
# [131]	train-rmse:0.09532	eval-rmse:0.58803
# [132]	train-rmse:0.094875	eval-rmse:0.587983
# [133]	train-rmse:0.094275	eval-rmse:0.587809
# [134]	train-rmse:0.092932	eval-rmse:0.587719
# [135]	train-rmse:0.092319	eval-rmse:0.587568
# [136]	train-rmse:0.092002	eval-rmse:0.58767
# [137]	train-rmse:0.091325	eval-rmse:0.587668
# [138]	train-rmse:0.089984	eval-rmse:0.587655
# [139]	train-rmse:0.089188	eval-rmse:0.587653
# [140]	train-rmse:0.088003	eval-rmse:0.587797
# [141]	train-rmse:0.087559	eval-rmse:0.58795
# Stopping. Best iteration:
# [121]	train-rmse:0.106469	eval-rmse:0.587533
#
# mean_squared_log_error: 0.5879495311152146
# save model: models/xgb_fold5.pkl
# ==================================================
# rmsle_mean: 0.5922452286955908
# xgb_oof
#    xgb_stacking
# 0      9.627528
# 1      9.337125
# 2      9.390121
# 3      9.037077
# 4     10.513770

# %%
df_oof.to_csv(f'input/train_xgb_out_of_fold.csv', index=False)

# %%
def predict_fold_avg(X_inference, model_name):
    """
    テストデータに対する予測
    5foldで作成したモデルのそれぞれの予測と平均をデータフレームで返す
    """
    list_preds_tmp = []
    for i in range(1, 6):
        model_path = f'models/{model_name}_fold{i}.pkl'
        model = pickle.load(open(model_path, 'rb'))
        pred = model.predict(xgb.DMatrix(X_inference))
        list_preds_tmp.append(pred)
    df_preds = pd.DataFrame({'model_1': np.squeeze(list_preds_tmp[0]),
                               'model_2': np.squeeze(list_preds_tmp[1]),
                               'model_3': np.squeeze(list_preds_tmp[2]),
                               'model_4': np.squeeze(list_preds_tmp[3]),
                               'model_5': np.squeeze(list_preds_tmp[4])})
    df_preds[f'{model_name}_stacking'] = df_preds.mean(axis=1)
    print(f'{model_name}_predict')
    print(df_preds.head())
    return df_preds[[f'{model_name}_stacking']]

# %%
df_preds = predict_fold_avg(X_inference, 'xgb')
# Out:
# xgb_predict
#      model_1   model_2   model_3   model_4   model_5  xgb_stacking
# 0   9.554907  9.450179  9.065234  9.788546  9.366606      9.445094
# 1  11.029101  9.554940  9.524618  9.772481  9.978577      9.971944
# 2   9.729311  9.366158  9.430955  9.392135  9.218604      9.427433
# 3   9.385055  9.447559  9.516781  9.556825  8.982764      9.377797
# 4   9.582204  9.507136  9.668526  8.892940  9.397411      9.409643

# %%
df_preds
# Out:
#       xgb_stacking
# 0         9.445094
# 1         9.971944
# 2         9.427433
# 3         9.377797
# 4         9.409643
# ...            ...
# 4991      9.403758
# 4992      9.156425
# 4993      9.267194
# 4994      8.835741
# 4995      9.253804
#
# [4996 rows x 1 columns]

# %%
df_preds.to_csv(f'input/test_xgb_out_of_fold.csv', index=False)

# %%
sample_sub[COL_Y] = np.expm1(df_preds['xgb_stacking'])
sample_sub.head()
# Out:
#    id             y
# 0   1  12644.972656
# 1   2  21416.076172
# 2   3  12423.591797
# 3   4  11821.941406
# 4   5  12204.514648

# %%
sample_sub.to_csv('submit/submission_xgboost.csv', index=False)

# %%
sample_sub[COL_Y] = np.expm1(df_preds['pred_avg'])
sample_sub.head()
# Out:
#    id             y
# 0   1  14281.859191
# 1   2  16134.749746
# 2   3  14674.358695
# 3   4  10660.970524
# 4   5  10309.487098

# %%
sample_sub.to_csv('submit/submission_lightgbm_1-1-0.csv', index=False)
