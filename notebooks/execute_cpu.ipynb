# %%
from google.colab import drive
drive.mount('/content/drive')
# カレントディレクトリの指定
import os
os.chdir('/content/drive/MyDrive/分析コンペ/05_ProbSpace/民泊サービスの宿泊料金予測/')
# Out:
# Mounted at /content/drive

# %% [markdown]
# !python src/create_model_hoge.py #1 #2 #3
#  - #1: モデルの名前
#  - #2: エンコードタイプ(one-hot or label-enc)
#  - #3: CVだけ確認(True), CV確認〜モデルの保存(False)

# %%
# !python src/create_model_lgbm.py 'lightgbm' 'label-enc' 'True'
# Out:
# model_name: lightgbm
# enc_type: label-enc
# model_save: True
# read data...
# Missing complement...
# ...
# fold: 1
# mean_squared_log_error: 0.5397018803053382
# ...
# fold: 2
# mean_squared_log_error: 0.5399967402785775
# ...
# fold: 3
# mean_squared_log_error: 0.5581953101623622
# ...
# fold: 4
# mean_squared_log_error: 0.5450425735342493
# ...
# fold: 5
# mean_squared_log_error: 0.5753574714774746
# ...
# rmsle_mean: 0.5516587951516004
# lightgbm_oof
#    lightgbm_stacking
# 0           9.548714
# 1           9.213942
# 2           9.305787
# 3           9.042127
# 4           9.877283
# lightgbm_predict
#      model_1  ...  lightgbm_stacking
# 0   9.389337  ...           9.432202
# 1  10.273746  ...           9.871946
# 2   9.598300  ...           9.595329
# 3   9.552239  ...           9.369932
# 4   9.150608  ...           9.293471
#
# [5 rows x 6 columns]
# finish

# %%
# !python src/create_model_of_sklearn.py 'ridge' 'one-hot' 'True'
# Out:
# model_name: ridge
# enc_type: one-hot
# monitoring: True
# read data...
# ...
# fold: 1
# score: 0.7219580174023617
# ...
# fold: 2
# score: 0.7087846449863348
# ...
# fold: 3
# score: 0.7082208941829197
# ...
# fold: 4
# score: 0.6980834252015805
# ...
# fold: 5
# score: 0.7144618384697727
# ...
# rmsle_mean: 0.7103017640485938
# ridge_oof
#    ridge_stacking
# 0       10.114502
# 1        8.360527
# 2        9.909695
# 3        9.356619
# 4       10.186260
# ridge_predict
#     model_1  ...  ridge_stacking
# 0  9.591553  ...        9.710025
# 1  9.931343  ...        9.713884
# 2  9.642212  ...        9.517798
# 3  8.688815  ...        9.154997
# 4  9.135264  ...        8.974034
#
# [5 rows x 6 columns]
# finish

# %%
# !python src/create_model_of_sklearn.py 'neighbors' 'one-hot' 'True'
# Out:
# model_name: neighbors
# enc_type: one-hot
# monitoring: True
# read data...
# ...
# fold: 1
# score: 0.6691665873087438
# ...
# fold: 2
# score: 0.6813371748130498
# ...
# fold: 3
# score: 0.6790074851853743
# ...
# fold: 4
# score: 0.611280294138932
# ...
# fold: 5
# score: 0.6318033113861943
# ...
# rmsle_mean: 0.6545189705664589
# neighbors_oof
#    neighbors_stacking
# 0            9.199690
# 1            9.288937
# 2            9.169691
# 3            9.098005
# 4            9.528909
# neighbors_predict
#      model_1  ...  neighbors_stacking
# 0   9.395848  ...            9.310863
# 1  10.357762  ...           10.109017
# 2   9.212122  ...            9.336297
# 3   8.837199  ...            9.192100
# 4   9.272168  ...            9.427344
#
# [5 rows x 6 columns]
# finish

# %%
# !python src/create_model_of_sklearn.py 'svr' 'one-hot' 'True'
# Out:
# model_name: svr
# enc_type: one-hot
# monitoring: True
# read data...
# ...
# fold: 1
# score: 0.5892892675796101
# ...
# fold: 2
# score: 0.583658886128499
# ...
# fold: 3
# score: 0.5873627559810725
# ...
# fold: 4
# score: 0.5426697484573461
# ...
# fold: 5
# score: 0.5653814257996443
# ...
# rmsle_mean: 0.5736724167892344
# svr_oof
#    svr_stacking
# 0      9.377393
# 1      9.220028
# 2      9.385733
# 3      9.090586
# 4      9.805191
# svr_predict
#     model_1  ...  svr_stacking
# 0  9.437139  ...      9.420764
# 1  9.964621  ...      9.715402
# 2  9.523198  ...      9.552163
# 3  9.149308  ...      9.214931
# 4  9.103727  ...      9.191017
#
# [5 rows x 6 columns]
# finish

# %%
# !python src/create_model_of_sklearn.py 'rf' 'label-enc' 'True'
# Out:
# model_name: rf
# enc_type: label-enc
# monitoring: True
# read data...
# ...
# fold: 1
# score: 0.6189949943752618
# ...
# fold: 2
# score: 0.5953525348401735
# ...
# fold: 3
# score: 0.5931324611946376
# ...
# fold: 4
# score: 0.5598235544248978
# ...
# fold: 5
# score: 0.5948472552205768
# ...
# rmsle_mean: 0.5924301600111095
# rf_oof
#    rf_stacking
# 0     9.849388
# 1     9.466440
# 2     9.635884
# 3     9.049234
# 4     9.789036
# rf_predict
#     model_1  ...  rf_stacking
# 0  9.578062  ...     9.523879
# 1  9.593342  ...     9.551622
# 2  9.471720  ...     9.531160
# 3  9.358494  ...     9.447652
# 4  9.588466  ...     9.527033
#
# [5 rows x 6 columns]
# finish
