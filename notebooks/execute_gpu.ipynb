# %%
from google.colab import drive
drive.mount('/content/drive')
# カレントディレクトリの指定
import os
os.chdir('/content/drive/MyDrive/分析コンペ/05_ProbSpace/民泊サービスの宿泊料金予測/')
# Out:
# Mounted at /content/drive

# %%
! nvidia-smi
# Out:
# Sun May  1 11:09:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# !python src/create_model_hoge.py #1 #2 #3
#  - #1: モデルの名前
#  - #2: エンコードタイプ(one-hot or label-enc)
#  - #3: CVだけ確認(True), CV確認〜モデルの保存(False)

# %%
# !python src/create_model_nn.py 'nn' 'one-hot' 'True'
# Out:
# model_name: nn
# enc_type: one-hot
# model_save: True
# read data...
# fold: 1
# ...
# epoch: 0
# 100% 125/125 [00:01<00:00, 93.20it/s]
# 100% 32/32 [00:00<00:00, 89.96it/s]
# train_loss: 8.7505, train_rmsle: 8.7505
# valid_loss: 7.7463, valid_rmsle: 7.7463
# --------------------------------------------------
# epoch: 1
# 100% 125/125 [00:01<00:00, 102.00it/s]
# 100% 32/32 [00:00<00:00, 96.98it/s]
# train_loss: 6.4410, train_rmsle: 6.4410
# valid_loss: 4.8771, valid_rmsle: 4.8771
# --------------------------------------------------
# epoch: 2
# 100% 125/125 [00:01<00:00, 104.50it/s]
# 100% 32/32 [00:00<00:00, 93.94it/s]
# train_loss: 3.2670, train_rmsle: 3.2670
# valid_loss: 1.4221, valid_rmsle: 1.4221
# --------------------------------------------------
# epoch: 3
# 100% 125/125 [00:01<00:00, 103.68it/s]
# 100% 32/32 [00:00<00:00, 93.67it/s]
# train_loss: 1.1977, train_rmsle: 1.1977
# valid_loss: 0.7809, valid_rmsle: 0.7809
# --------------------------------------------------
# epoch: 4
# ...
